# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/ML-LaDECO/LaDECO
# Out:
# /content/drive/MyDrive/ML-LaDECO/LaDECO

# %%
import tensorflow as tf
print('TensorFlow Version',tf.__version__)
# Out:
# TensorFlow Version 2.8.0

# %%
import numpy as np

print('Project MLaDECO')
print('Author: Viswambhar Yasa')
print('Software version: 0.1')
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf
from tensorflow.keras import models
from thermograms.Utilities import Utilities
from ml_training.dataset_generation.fourier_transformation import fourier_transformation
from ml_training.dataset_generation.principal_componant_analysis import principal_componant_analysis
from utilites.segmentation_colormap_anno import segmentation_colormap_anno
from utilites.tolerance_maks_gen import tolerance_predicted_mask
import matplotlib.pyplot as plt
# Out:
# Project MLaDECO
# Author: Viswambhar Yasa
# Software version: 0.1
# 1

# %%
root_path = r'utilites/datasets'
data_file_name = r'Variantenvergleich_data.hdf5'
thermal_class = Utilities()
thermal_data,experiment_list=thermal_class.open_file(root_path, data_file_name,True)
experiment_name=r'2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 10s'
experimental_data=thermal_data[experiment_name]
# Out:
# Experiments in the file
#
# 1  :  2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 0°
# 2  :  2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 30°
# 3  :  2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 45°
# 4  :  2021-05-11 - Variantenvergleich - VarioTherm IR-Strahler - Winkel 0°
# 5  :  2021-05-11 - Variantenvergleich - VarioTherm IR-Strahler - Winkel 30°
# 6  :  2021-05-11 - Variantenvergleich - VarioTherm IR-Strahler - Winkel 45°
# 7  :  2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 10s
# 8  :  2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 2s
# 9  :  2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 5s
#
#
# A total of 9 experiments are loaded in file

# %%
input_data, reflection_st_index, reflection_end_index = fourier_transformation(experimental_data,
                                                                               scaling_type='normalization', index=1)
# Out:
# reflection_start_index:  156   reflection_end_index:  728
# The size of filtered data: (255, 256, 572)

# %%
from ml_training.dataset_generation.data_preprocessing import data_preprocessing1

# %%
#from data_train_test import data_preprocessing
#from data_train_test import data_preprocessing
dataset_genertor=data_preprocessing1()

# %%
from utilites.segmentation_colormap_anno import segmentation_colormap_anno
combined_mask=np.load('ml_training/dataset_generation/annots/2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 0°.npy')
segmentation_colormap_anno(combined_mask, heatmap='RdYlBu_r', file_name='seg_mask', disp=True)

# %%
annotation_path=r'ml_training/dataset_generation/annots//'
train_ds,valid_ds,test_ds=dataset_genertor.load_image_segmentation_dataset(thermal_data,experiment_list,annotation_path,save=True)
#training_dataset,validation_dataset,testing_dataset=dataset_genertor.load_image_segmentation_dataset(thermal_data,experiment_list,annotation_path)
# Out:
# 2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 0°
# 217 738
# (255, 256, 521)
# filtered dataset shape : (256, 256, 521) Shape after concatenation : (256, 256, 521)
# 2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 30°
# 270 675
# (255, 256, 405)
# filtered dataset shape : (256, 256, 405) Shape after concatenation : (256, 256, 926)
# 2021-05-11 - Variantenvergleich - VarioTherm Halogenlampe - Winkel 45°
# 162 728
# (255, 256, 566)
# filtered dataset shape : (256, 256, 566) Shape after concatenation : (256, 256, 1492)
# 2021-05-11 - Variantenvergleich - VarioTherm IR-Strahler - Winkel 0°
# 93 610
# (255, 256, 517)
# filtered dataset shape : (256, 256, 517) Shape after concatenation : (256, 256, 2009)
# 2021-05-11 - Variantenvergleich - VarioTherm IR-Strahler - Winkel 30°
# 143 660
# (255, 256, 517)
# filtered dataset shape : (256, 256, 517) Shape after concatenation : (256, 256, 2526)
# 2021-05-11 - Variantenvergleich - VarioTherm IR-Strahler - Winkel 45°
# 151 665
# (255, 256, 514)
# filtered dataset shape : (256, 256, 514) Shape after concatenation : (256, 256, 3040)
# 2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 10s
# 161 728
# (255, 256, 567)
# filtered dataset shape : (256, 256, 567) Shape after concatenation : (256, 256, 3607)
# 2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 2s
# 118 287
# (255, 256, 169)
# filtered dataset shape : (256, 256, 169) Shape after concatenation : (256, 256, 3776)
# 2021-05-25 - Variantenvergleich - VarioTherm Halogenlampe - Belichtungszeit 5s
# 154 333
# (255, 256, 179)
# filtered dataset shape : (256, 256, 179) Shape after concatenation : (256, 256, 3955)

# %%
train_dataset=dataset_genertor.create_dataset(train_ds[0], train_ds[1])
valid_dataset=dataset_genertor.create_dataset(np.array(valid_ds[0]), valid_ds[1])
test_dataset=dataset_genertor.create_dataset(test_ds[0], test_ds[1])

# %%
repeated_ds=train_dataset.repeat(6)
len(repeated_ds),len(train_dataset)
# Out:
# (16608, 2768)

# %%
from ml_training.dataset_generation.principal_componant_analysis import Augment

# %%
tf.data.experimental.enable_debug_mode()

# %%
AUTOTUNE = tf.data.AUTOTUNE
aug_train_ds = repeated_ds.map(lambda img,msk: Augment((img,msk)), num_parallel_calls=AUTOTUNE)
aug_test_ds = test_dataset.map(lambda img,msk: Augment((img,msk)), num_parallel_calls=AUTOTUNE)

# %%
batch_size=64

# %%
training_dataset = aug_train_ds.batch(batch_size)
#training_dataset=aug_train_ds.batch(batch_size)
validation_dataset=valid_dataset.batch(batch_size)
#validation_dataset = new_validation_dataset.batch(batch_size)
test_dataset = aug_test_ds.batch(batch_size)
len(train_dataset),len(validation_dataset),len(test_dataset)
# Out:
# (2768, 13, 6)

# %%
import seaborn as sns
from matplotlib.patches import Patch
data=next(iter(training_dataset))
i=23
image=data[0][i]
plots_image=np.squeeze(image)
true_anno=data[1][i]
anno1=np.zeros((256,256))
for i in range(4):
  temp=true_anno[:,:,i]
  anno1[temp==1]+=i
fig = plt.figure(figsize=(10, 7))
  
fig.add_subplot(1, 2, 1)
# showing image
plt.imshow(np.squeeze(image),cmap='RdYlBu_r')
plt.axis('off')
plt.title("Thernogram")
  

fig.add_subplot(1, 2, 2)
cmap = sns.mpl_palette("Set2", 4)
c=sns.heatmap(data=anno1, cmap=cmap, cbar=False)
plt.axis('off')

legend_handles = [Patch(color=cmap[0], label='Coating'),  # red
                  Patch(color=cmap[1], label='Substrate'),
                  Patch(color=cmap[2], label='Damaged Substrate'),
                  Patch(color=cmap[3], label='Thermal band')]  # green
plt.legend(handles=legend_handles, ncol=2, bbox_to_anchor=[0.5, 1.02], loc='upper center', fontsize=12, handlelength=.8)
fig = c.get_figure()
# showing image
plt.imshow(anno1,cmap='RdYlBu_r')
#plt.axis('off')
plt.title("Expected Mask")
# Out:
# Text(0.5, 1.0, 'Expected Mask')

# %%
from therml.ml_models import U_Net
# Out:
#   File "/content/drive/MyDrive/ML-LaDECO/LaDECO/therml/ml_models.py", line 307
#     def __init__(self):
#                        ^
# IndentationError: unindent does not match any outer indentation level

# %%
number_of_classes = 4
input_shape = (256, 256, 1)
filter_list = np.array([8,16,32,64, 128, 256,512])
u_net=U_Net()
segementation_model=u_net.create_model(number_of_classes,input_shape,filter_list,disp=False)
# Out:
# Building U-NET model
#
# Input shape : (None, 256, 256, 1)
# pipline encoder output shape: (None, 4, 4, 256)
# pipline bottle-neck output shape: (None, 4, 4, 512)
# pipline decoder output shape: (None, 256, 256, 8)
# output shape (None, 256, 256, 4)
#
# Model built sucessfully

# %%
segementation_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 8)  80          ['input_3[0][0]']
#
#  dropout (Dropout)              (None, 256, 256, 8)  0           ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 8)  0           ['dropout[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  1168        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)  0           ['dropout_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)  0           ['dropout_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)  0           ['dropout_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)   0           ['dropout_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_5[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 256)   0           ['dropout_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 4, 4, 512)    1180160     ['max_pooling2d_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 4, 4, 512)    0           ['conv2d_6[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   524544      ['dropout_6[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    1179904     ['concatenate[0][0]']
#
#  dropout_7 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_7[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 128)  131200     ['conv2d_8[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  295040      ['concatenate_1[0][0]']
#
#  dropout_8 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_8[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_10[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_2[0][0]']
#
#  dropout_9 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_9[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_12[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_3[0][0]']
#
#  dropout_10 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_10[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_14[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'dropout_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_4[0][0]']
#                                 )
#
#  dropout_11 (Dropout)           (None, 128, 128, 16  0           ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_11[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 256, 256, 8)  520        ['conv2d_16[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 16  0           ['conv2d_transpose_5[0][0]',
#                                 )                                 'dropout[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 8)  1160        ['concatenate_5[0][0]']
#
#  dropout_12 (Dropout)           (None, 256, 256, 8)  0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 8)  584         ['dropout_12[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 4)  36          ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 4,632,716
# Trainable params: 4,632,716
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10)
estop=tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=10,restore_best_weights=True)
callbacks=[rlronp, estop]

# %%
from datetime import datetime
import math

def step_decay(epoch):
	initial_lrate = 0.05
	drop = 0.5
	epochs_drop = 20
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate
lr_callback = tf.keras.callbacks.LearningRateScheduler(step_decay)

# %%
segementation_model.compile(loss=tf.keras.losses.categorical_crossentropy,
    #loss=dice_coef_loss,
              optimizer=tf.keras.optimizers.Adam(learning_rate=1E-3),
              metrics=[tf.keras.metrics.MeanIoU(num_classes=4),
              'accuracy'])

# %%
model_history = segementation_model.fit(training_dataset,batch_size=64,epochs=len(training_dataset),steps_per_epoch=1,verbose=1,shuffle=True,
                                        validation_data=validation_dataset,validation_batch_size=8,validation_steps=1,
                                        callbacks=callbacks)
# Out:
# Epoch 1/260
# 1/1 [==============================] - 19s 19s/step - loss: 2.0495 - mean_io_u: 0.3750 - accuracy: 0.2578 - val_loss: 1.8801 - val_mean_io_u: 0.3750 - val_accuracy: 0.2584 - lr: 0.0010
# Epoch 2/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.9120 - mean_io_u: 0.3750 - accuracy: 0.2566 - val_loss: 1.7719 - val_mean_io_u: 0.3750 - val_accuracy: 0.2609 - lr: 0.0010
# Epoch 3/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.7995 - mean_io_u: 0.3750 - accuracy: 0.2657 - val_loss: 1.6610 - val_mean_io_u: 0.3750 - val_accuracy: 0.2623 - lr: 0.0010
# Epoch 4/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.6914 - mean_io_u: 0.3750 - accuracy: 0.2878 - val_loss: 1.5586 - val_mean_io_u: 0.3750 - val_accuracy: 0.2795 - lr: 0.0010
# Epoch 5/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.6069 - mean_io_u: 0.3750 - accuracy: 0.3169 - val_loss: 1.4974 - val_mean_io_u: 0.3750 - val_accuracy: 0.2726 - lr: 0.0010
# Epoch 6/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.5239 - mean_io_u: 0.3750 - accuracy: 0.3199 - val_loss: 1.4422 - val_mean_io_u: 0.3750 - val_accuracy: 0.2775 - lr: 0.0010
# Epoch 7/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.4581 - mean_io_u: 0.3750 - accuracy: 0.3348 - val_loss: 1.3959 - val_mean_io_u: 0.3750 - val_accuracy: 0.2960 - lr: 0.0010
# Epoch 8/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.4028 - mean_io_u: 0.3750 - accuracy: 0.3545 - val_loss: 1.3542 - val_mean_io_u: 0.3750 - val_accuracy: 0.3144 - lr: 0.0010
# Epoch 9/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.3555 - mean_io_u: 0.3750 - accuracy: 0.3750 - val_loss: 1.3182 - val_mean_io_u: 0.3750 - val_accuracy: 0.3744 - lr: 0.0010
# Epoch 10/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.3119 - mean_io_u: 0.3750 - accuracy: 0.4011 - val_loss: 1.2874 - val_mean_io_u: 0.3750 - val_accuracy: 0.4504 - lr: 0.0010
# Epoch 11/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.2782 - mean_io_u: 0.3750 - accuracy: 0.4275 - val_loss: 1.2619 - val_mean_io_u: 0.3750 - val_accuracy: 0.4874 - lr: 0.0010
# Epoch 12/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.2434 - mean_io_u: 0.3750 - accuracy: 0.4575 - val_loss: 1.2336 - val_mean_io_u: 0.3750 - val_accuracy: 0.5092 - lr: 0.0010
# Epoch 13/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.2076 - mean_io_u: 0.3750 - accuracy: 0.4888 - val_loss: 1.1964 - val_mean_io_u: 0.3750 - val_accuracy: 0.5479 - lr: 0.0010
# Epoch 14/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.1681 - mean_io_u: 0.3750 - accuracy: 0.5190 - val_loss: 1.1561 - val_mean_io_u: 0.3750 - val_accuracy: 0.5866 - lr: 0.0010
# Epoch 15/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.1412 - mean_io_u: 0.3750 - accuracy: 0.5396 - val_loss: 1.1175 - val_mean_io_u: 0.3750 - val_accuracy: 0.5986 - lr: 0.0010
# Epoch 16/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.0907 - mean_io_u: 0.3750 - accuracy: 0.5672 - val_loss: 1.0814 - val_mean_io_u: 0.3750 - val_accuracy: 0.6071 - lr: 0.0010
# Epoch 17/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.0540 - mean_io_u: 0.3750 - accuracy: 0.5848 - val_loss: 1.0467 - val_mean_io_u: 0.3750 - val_accuracy: 0.6161 - lr: 0.0010
# Epoch 18/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.0264 - mean_io_u: 0.3750 - accuracy: 0.5989 - val_loss: 1.0120 - val_mean_io_u: 0.3750 - val_accuracy: 0.6290 - lr: 0.0010
# Epoch 19/260
# 1/1 [==============================] - 2s 2s/step - loss: 1.0014 - mean_io_u: 0.3751 - accuracy: 0.6097 - val_loss: 0.9780 - val_mean_io_u: 0.3750 - val_accuracy: 0.6497 - lr: 0.0010
# Epoch 20/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.9836 - mean_io_u: 0.3753 - accuracy: 0.6200 - val_loss: 0.9499 - val_mean_io_u: 0.3750 - val_accuracy: 0.6633 - lr: 0.0010
# Epoch 21/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.9549 - mean_io_u: 0.3755 - accuracy: 0.6343 - val_loss: 0.9293 - val_mean_io_u: 0.3750 - val_accuracy: 0.6780 - lr: 0.0010
# Epoch 22/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.9264 - mean_io_u: 0.3760 - accuracy: 0.6407 - val_loss: 0.9144 - val_mean_io_u: 0.3750 - val_accuracy: 0.6857 - lr: 0.0010
# Epoch 23/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.9141 - mean_io_u: 0.3768 - accuracy: 0.6510 - val_loss: 0.9030 - val_mean_io_u: 0.3751 - val_accuracy: 0.6917 - lr: 0.0010
# Epoch 24/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.9321 - mean_io_u: 0.3785 - accuracy: 0.6498 - val_loss: 0.8938 - val_mean_io_u: 0.3751 - val_accuracy: 0.6934 - lr: 0.0010
# Epoch 25/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8832 - mean_io_u: 0.3791 - accuracy: 0.6548 - val_loss: 0.8872 - val_mean_io_u: 0.3752 - val_accuracy: 0.6945 - lr: 0.0010
# Epoch 26/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8957 - mean_io_u: 0.3800 - accuracy: 0.6602 - val_loss: 0.8820 - val_mean_io_u: 0.3752 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 27/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8949 - mean_io_u: 0.3802 - accuracy: 0.6611 - val_loss: 0.8778 - val_mean_io_u: 0.3752 - val_accuracy: 0.6954 - lr: 0.0010
# Epoch 28/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8757 - mean_io_u: 0.3800 - accuracy: 0.6645 - val_loss: 0.8719 - val_mean_io_u: 0.3752 - val_accuracy: 0.6947 - lr: 0.0010
# Epoch 29/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8727 - mean_io_u: 0.3800 - accuracy: 0.6580 - val_loss: 0.8650 - val_mean_io_u: 0.3753 - val_accuracy: 0.6948 - lr: 0.0010
# Epoch 30/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8724 - mean_io_u: 0.3798 - accuracy: 0.6677 - val_loss: 0.8555 - val_mean_io_u: 0.3752 - val_accuracy: 0.6958 - lr: 0.0010
# Epoch 31/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8709 - mean_io_u: 0.3802 - accuracy: 0.6737 - val_loss: 0.8525 - val_mean_io_u: 0.3751 - val_accuracy: 0.6954 - lr: 0.0010
# Epoch 32/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8440 - mean_io_u: 0.3778 - accuracy: 0.6778 - val_loss: 0.8509 - val_mean_io_u: 0.3751 - val_accuracy: 0.6966 - lr: 0.0010
# Epoch 33/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8259 - mean_io_u: 0.3770 - accuracy: 0.6802 - val_loss: 0.8341 - val_mean_io_u: 0.3751 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 34/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8303 - mean_io_u: 0.3772 - accuracy: 0.6881 - val_loss: 0.8384 - val_mean_io_u: 0.3750 - val_accuracy: 0.6932 - lr: 0.0010
# Epoch 35/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8390 - mean_io_u: 0.3764 - accuracy: 0.6708 - val_loss: 0.8406 - val_mean_io_u: 0.3750 - val_accuracy: 0.6963 - lr: 0.0010
# Epoch 36/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8440 - mean_io_u: 0.3759 - accuracy: 0.6645 - val_loss: 0.8481 - val_mean_io_u: 0.3750 - val_accuracy: 0.7091 - lr: 0.0010
# Epoch 37/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8195 - mean_io_u: 0.3763 - accuracy: 0.6765 - val_loss: 0.8344 - val_mean_io_u: 0.3750 - val_accuracy: 0.7148 - lr: 0.0010
# Epoch 38/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8029 - mean_io_u: 0.3774 - accuracy: 0.6928 - val_loss: 0.8137 - val_mean_io_u: 0.3751 - val_accuracy: 0.7203 - lr: 0.0010
# Epoch 39/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8243 - mean_io_u: 0.3936 - accuracy: 0.7031 - val_loss: 0.7917 - val_mean_io_u: 0.3750 - val_accuracy: 0.7133 - lr: 0.0010
# Epoch 40/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8263 - mean_io_u: 0.3841 - accuracy: 0.7002 - val_loss: 0.7884 - val_mean_io_u: 0.3750 - val_accuracy: 0.7092 - lr: 0.0010
# Epoch 41/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7388 - mean_io_u: 0.3760 - accuracy: 0.7051 - val_loss: 0.7805 - val_mean_io_u: 0.3750 - val_accuracy: 0.7204 - lr: 0.0010
# Epoch 42/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7395 - mean_io_u: 0.3757 - accuracy: 0.7178 - val_loss: 0.7571 - val_mean_io_u: 0.3750 - val_accuracy: 0.7448 - lr: 0.0010
# Epoch 43/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8045 - mean_io_u: 0.3776 - accuracy: 0.7229 - val_loss: 0.8113 - val_mean_io_u: 0.3750 - val_accuracy: 0.7350 - lr: 0.0010
# Epoch 44/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7959 - mean_io_u: 0.3752 - accuracy: 0.6981 - val_loss: 0.8270 - val_mean_io_u: 0.3750 - val_accuracy: 0.7575 - lr: 0.0010
# Epoch 45/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8138 - mean_io_u: 0.3752 - accuracy: 0.7000 - val_loss: 0.8348 - val_mean_io_u: 0.3750 - val_accuracy: 0.7591 - lr: 0.0010
# Epoch 46/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8127 - mean_io_u: 0.3752 - accuracy: 0.7102 - val_loss: 0.8079 - val_mean_io_u: 0.3750 - val_accuracy: 0.7714 - lr: 0.0010
# Epoch 47/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.8033 - mean_io_u: 0.3752 - accuracy: 0.7125 - val_loss: 0.7749 - val_mean_io_u: 0.3750 - val_accuracy: 0.7754 - lr: 0.0010
# Epoch 48/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7744 - mean_io_u: 0.3755 - accuracy: 0.7209 - val_loss: 0.7521 - val_mean_io_u: 0.3750 - val_accuracy: 0.7787 - lr: 0.0010
# Epoch 49/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7584 - mean_io_u: 0.3757 - accuracy: 0.7283 - val_loss: 0.7490 - val_mean_io_u: 0.3750 - val_accuracy: 0.7529 - lr: 0.0010
# Epoch 50/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7737 - mean_io_u: 0.3766 - accuracy: 0.7233 - val_loss: 0.7123 - val_mean_io_u: 0.3751 - val_accuracy: 0.7803 - lr: 0.0010
# Epoch 51/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7501 - mean_io_u: 0.3768 - accuracy: 0.7350 - val_loss: 0.7276 - val_mean_io_u: 0.3751 - val_accuracy: 0.7759 - lr: 0.0010
# Epoch 52/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7042 - mean_io_u: 0.3766 - accuracy: 0.7540 - val_loss: 0.7712 - val_mean_io_u: 0.3751 - val_accuracy: 0.7295 - lr: 0.0010
# Epoch 53/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7170 - mean_io_u: 0.3771 - accuracy: 0.7540 - val_loss: 0.7402 - val_mean_io_u: 0.3751 - val_accuracy: 0.7569 - lr: 0.0010
# Epoch 54/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.7004 - mean_io_u: 0.3771 - accuracy: 0.7597 - val_loss: 0.6979 - val_mean_io_u: 0.3751 - val_accuracy: 0.7719 - lr: 0.0010
# Epoch 55/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6623 - mean_io_u: 0.3766 - accuracy: 0.7670 - val_loss: 0.6920 - val_mean_io_u: 0.3751 - val_accuracy: 0.7583 - lr: 0.0010
# Epoch 56/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6712 - mean_io_u: 0.3778 - accuracy: 0.7593 - val_loss: 0.6772 - val_mean_io_u: 0.3751 - val_accuracy: 0.7655 - lr: 0.0010
# Epoch 57/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6534 - mean_io_u: 0.3769 - accuracy: 0.7718 - val_loss: 0.6872 - val_mean_io_u: 0.3750 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 58/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6888 - mean_io_u: 0.3761 - accuracy: 0.7596 - val_loss: 0.7129 - val_mean_io_u: 0.3750 - val_accuracy: 0.7349 - lr: 0.0010
# Epoch 59/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6398 - mean_io_u: 0.3757 - accuracy: 0.7608 - val_loss: 0.6759 - val_mean_io_u: 0.3750 - val_accuracy: 0.7653 - lr: 0.0010
# Epoch 60/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6667 - mean_io_u: 0.3753 - accuracy: 0.7706 - val_loss: 0.7108 - val_mean_io_u: 0.3750 - val_accuracy: 0.7249 - lr: 0.0010
# Epoch 61/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6360 - mean_io_u: 0.3769 - accuracy: 0.7624 - val_loss: 0.6683 - val_mean_io_u: 0.3750 - val_accuracy: 0.7669 - lr: 0.0010
# Epoch 62/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6555 - mean_io_u: 0.3756 - accuracy: 0.7716 - val_loss: 0.6620 - val_mean_io_u: 0.3750 - val_accuracy: 0.7700 - lr: 0.0010
# Epoch 63/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6186 - mean_io_u: 0.3755 - accuracy: 0.7766 - val_loss: 0.6691 - val_mean_io_u: 0.3750 - val_accuracy: 0.7595 - lr: 0.0010
# Epoch 64/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6122 - mean_io_u: 0.3768 - accuracy: 0.7817 - val_loss: 0.6535 - val_mean_io_u: 0.3750 - val_accuracy: 0.7688 - lr: 0.0010
# Epoch 65/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6319 - mean_io_u: 0.3764 - accuracy: 0.7727 - val_loss: 0.6477 - val_mean_io_u: 0.3750 - val_accuracy: 0.7721 - lr: 0.0010
# Epoch 66/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6040 - mean_io_u: 0.3759 - accuracy: 0.7825 - val_loss: 0.6569 - val_mean_io_u: 0.3750 - val_accuracy: 0.7648 - lr: 0.0010
# Epoch 67/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5993 - mean_io_u: 0.3763 - accuracy: 0.7823 - val_loss: 0.6434 - val_mean_io_u: 0.3750 - val_accuracy: 0.7728 - lr: 0.0010
# Epoch 68/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6000 - mean_io_u: 0.3760 - accuracy: 0.7817 - val_loss: 0.6301 - val_mean_io_u: 0.3750 - val_accuracy: 0.7810 - lr: 0.0010
# Epoch 69/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6039 - mean_io_u: 0.3757 - accuracy: 0.7796 - val_loss: 0.6526 - val_mean_io_u: 0.3750 - val_accuracy: 0.7689 - lr: 0.0010
# Epoch 70/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6094 - mean_io_u: 0.3771 - accuracy: 0.7814 - val_loss: 0.6502 - val_mean_io_u: 0.3750 - val_accuracy: 0.7718 - lr: 0.0010
# Epoch 71/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5805 - mean_io_u: 0.3773 - accuracy: 0.7886 - val_loss: 0.6266 - val_mean_io_u: 0.3750 - val_accuracy: 0.7822 - lr: 0.0010
# Epoch 72/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5737 - mean_io_u: 0.3786 - accuracy: 0.7882 - val_loss: 0.6072 - val_mean_io_u: 0.3750 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 73/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5697 - mean_io_u: 0.3822 - accuracy: 0.7898 - val_loss: 0.6054 - val_mean_io_u: 0.3750 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 74/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5910 - mean_io_u: 0.3819 - accuracy: 0.7832 - val_loss: 0.6057 - val_mean_io_u: 0.3750 - val_accuracy: 0.7838 - lr: 0.0010
# Epoch 75/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5924 - mean_io_u: 0.3781 - accuracy: 0.7797 - val_loss: 0.6180 - val_mean_io_u: 0.3750 - val_accuracy: 0.7836 - lr: 0.0010
# Epoch 76/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5563 - mean_io_u: 0.3769 - accuracy: 0.7939 - val_loss: 0.6498 - val_mean_io_u: 0.3750 - val_accuracy: 0.7670 - lr: 0.0010
# Epoch 77/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5609 - mean_io_u: 0.3785 - accuracy: 0.7918 - val_loss: 0.5907 - val_mean_io_u: 0.3750 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 78/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5462 - mean_io_u: 0.3802 - accuracy: 0.7953 - val_loss: 0.5623 - val_mean_io_u: 0.3750 - val_accuracy: 0.7945 - lr: 0.0010
# Epoch 79/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5709 - mean_io_u: 0.3855 - accuracy: 0.7870 - val_loss: 0.6131 - val_mean_io_u: 0.3750 - val_accuracy: 0.7726 - lr: 0.0010
# Epoch 80/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5780 - mean_io_u: 0.4036 - accuracy: 0.7942 - val_loss: 0.5708 - val_mean_io_u: 0.3750 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 81/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5908 - mean_io_u: 0.3758 - accuracy: 0.7877 - val_loss: 0.6311 - val_mean_io_u: 0.3750 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 82/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5948 - mean_io_u: 0.3772 - accuracy: 0.7796 - val_loss: 0.7040 - val_mean_io_u: 0.3750 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 83/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.6430 - mean_io_u: 0.3816 - accuracy: 0.7713 - val_loss: 0.6888 - val_mean_io_u: 0.3750 - val_accuracy: 0.7461 - lr: 0.0010
# Epoch 84/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5991 - mean_io_u: 0.3857 - accuracy: 0.7817 - val_loss: 0.6105 - val_mean_io_u: 0.3750 - val_accuracy: 0.7921 - lr: 0.0010
# Epoch 85/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5489 - mean_io_u: 0.3843 - accuracy: 0.7962 - val_loss: 0.5579 - val_mean_io_u: 0.3750 - val_accuracy: 0.7993 - lr: 0.0010
# Epoch 86/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5595 - mean_io_u: 0.3827 - accuracy: 0.7900 - val_loss: 0.5427 - val_mean_io_u: 0.3750 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 87/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5725 - mean_io_u: 0.3888 - accuracy: 0.7851 - val_loss: 0.5606 - val_mean_io_u: 0.3750 - val_accuracy: 0.7994 - lr: 0.0010
# Epoch 88/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5511 - mean_io_u: 0.4002 - accuracy: 0.7941 - val_loss: 0.5791 - val_mean_io_u: 0.3750 - val_accuracy: 0.7963 - lr: 0.0010
# Epoch 89/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5423 - mean_io_u: 0.3862 - accuracy: 0.7990 - val_loss: 0.5898 - val_mean_io_u: 0.3750 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 90/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5495 - mean_io_u: 0.3775 - accuracy: 0.7884 - val_loss: 0.5957 - val_mean_io_u: 0.3750 - val_accuracy: 0.7977 - lr: 0.0010
# Epoch 91/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5558 - mean_io_u: 0.3758 - accuracy: 0.7885 - val_loss: 0.5920 - val_mean_io_u: 0.3750 - val_accuracy: 0.7977 - lr: 0.0010
# Epoch 92/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5517 - mean_io_u: 0.3758 - accuracy: 0.7924 - val_loss: 0.5851 - val_mean_io_u: 0.3750 - val_accuracy: 0.7963 - lr: 0.0010
# Epoch 93/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5420 - mean_io_u: 0.3796 - accuracy: 0.7896 - val_loss: 0.5753 - val_mean_io_u: 0.3750 - val_accuracy: 0.7954 - lr: 0.0010
# Epoch 94/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5252 - mean_io_u: 0.3908 - accuracy: 0.7956 - val_loss: 0.5606 - val_mean_io_u: 0.3750 - val_accuracy: 0.7975 - lr: 0.0010
# Epoch 95/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5105 - mean_io_u: 0.4067 - accuracy: 0.8019 - val_loss: 0.5426 - val_mean_io_u: 0.3750 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 96/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5055 - mean_io_u: 0.4128 - accuracy: 0.8054 - val_loss: 0.5305 - val_mean_io_u: 0.3750 - val_accuracy: 0.8030 - lr: 0.0010
# Epoch 97/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5229 - mean_io_u: 0.3996 - accuracy: 0.7979 - val_loss: 0.5351 - val_mean_io_u: 0.3750 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 98/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5057 - mean_io_u: 0.3874 - accuracy: 0.8007 - val_loss: 0.5499 - val_mean_io_u: 0.3750 - val_accuracy: 0.8014 - lr: 0.0010
# Epoch 99/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5125 - mean_io_u: 0.3854 - accuracy: 0.7948 - val_loss: 0.5655 - val_mean_io_u: 0.3750 - val_accuracy: 0.7981 - lr: 0.0010
# Epoch 100/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5096 - mean_io_u: 0.3862 - accuracy: 0.7990 - val_loss: 0.5638 - val_mean_io_u: 0.3750 - val_accuracy: 0.7989 - lr: 0.0010
# Epoch 101/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5295 - mean_io_u: 0.3897 - accuracy: 0.7935 - val_loss: 0.5487 - val_mean_io_u: 0.3750 - val_accuracy: 0.8030 - lr: 0.0010
# Epoch 102/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4979 - mean_io_u: 0.3965 - accuracy: 0.7984 - val_loss: 0.5310 - val_mean_io_u: 0.3750 - val_accuracy: 0.8052 - lr: 0.0010
# Epoch 103/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.5100 - mean_io_u: 0.4039 - accuracy: 0.7958 - val_loss: 0.5227 - val_mean_io_u: 0.3750 - val_accuracy: 0.8057 - lr: 0.0010
# Epoch 104/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4739 - mean_io_u: 0.4176 - accuracy: 0.8049 - val_loss: 0.5262 - val_mean_io_u: 0.3759 - val_accuracy: 0.8053 - lr: 0.0010
# Epoch 105/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4835 - mean_io_u: 0.4455 - accuracy: 0.8063 - val_loss: 0.5250 - val_mean_io_u: 0.3768 - val_accuracy: 0.8049 - lr: 0.0010
# Epoch 106/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4964 - mean_io_u: 0.4496 - accuracy: 0.7990 - val_loss: 0.5203 - val_mean_io_u: 0.3753 - val_accuracy: 0.8056 - lr: 0.0010
# Epoch 107/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4843 - mean_io_u: 0.4366 - accuracy: 0.8074 - val_loss: 0.5153 - val_mean_io_u: 0.3750 - val_accuracy: 0.8057 - lr: 0.0010
# Epoch 108/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4926 - mean_io_u: 0.4083 - accuracy: 0.8006 - val_loss: 0.5315 - val_mean_io_u: 0.3750 - val_accuracy: 0.8025 - lr: 0.0010
# Epoch 109/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4859 - mean_io_u: 0.4057 - accuracy: 0.7991 - val_loss: 0.5380 - val_mean_io_u: 0.3750 - val_accuracy: 0.7977 - lr: 0.0010
# Epoch 110/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4566 - mean_io_u: 0.4127 - accuracy: 0.8169 - val_loss: 0.5167 - val_mean_io_u: 0.3753 - val_accuracy: 0.8028 - lr: 0.0010
# Epoch 111/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4743 - mean_io_u: 0.4189 - accuracy: 0.8034 - val_loss: 0.4918 - val_mean_io_u: 0.3764 - val_accuracy: 0.8088 - lr: 0.0010
# Epoch 112/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4775 - mean_io_u: 0.4297 - accuracy: 0.8023 - val_loss: 0.4959 - val_mean_io_u: 0.3773 - val_accuracy: 0.8085 - lr: 0.0010
# Epoch 113/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4793 - mean_io_u: 0.4393 - accuracy: 0.8056 - val_loss: 0.5088 - val_mean_io_u: 0.3759 - val_accuracy: 0.8065 - lr: 0.0010
# Epoch 114/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4726 - mean_io_u: 0.4392 - accuracy: 0.8030 - val_loss: 0.5042 - val_mean_io_u: 0.3750 - val_accuracy: 0.8108 - lr: 0.0010
# Epoch 115/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4440 - mean_io_u: 0.4257 - accuracy: 0.8141 - val_loss: 0.4961 - val_mean_io_u: 0.3750 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 116/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4575 - mean_io_u: 0.4254 - accuracy: 0.8049 - val_loss: 0.4987 - val_mean_io_u: 0.3754 - val_accuracy: 0.8109 - lr: 0.0010
# Epoch 117/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4679 - mean_io_u: 0.4460 - accuracy: 0.8064 - val_loss: 0.4831 - val_mean_io_u: 0.3763 - val_accuracy: 0.8131 - lr: 0.0010
# Epoch 118/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4750 - mean_io_u: 0.4562 - accuracy: 0.8003 - val_loss: 0.4724 - val_mean_io_u: 0.3759 - val_accuracy: 0.8146 - lr: 0.0010
# Epoch 119/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4652 - mean_io_u: 0.4407 - accuracy: 0.8034 - val_loss: 0.5071 - val_mean_io_u: 0.3766 - val_accuracy: 0.8080 - lr: 0.0010
# Epoch 120/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4315 - mean_io_u: 0.4562 - accuracy: 0.8219 - val_loss: 0.5199 - val_mean_io_u: 0.3771 - val_accuracy: 0.8020 - lr: 0.0010
# Epoch 121/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4616 - mean_io_u: 0.4663 - accuracy: 0.8089 - val_loss: 0.4715 - val_mean_io_u: 0.3758 - val_accuracy: 0.8157 - lr: 0.0010
# Epoch 122/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4677 - mean_io_u: 0.4443 - accuracy: 0.8067 - val_loss: 0.4796 - val_mean_io_u: 0.3770 - val_accuracy: 0.8159 - lr: 0.0010
# Epoch 123/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4431 - mean_io_u: 0.4671 - accuracy: 0.8122 - val_loss: 0.5063 - val_mean_io_u: 0.3825 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 124/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4452 - mean_io_u: 0.5061 - accuracy: 0.8161 - val_loss: 0.4642 - val_mean_io_u: 0.3792 - val_accuracy: 0.8179 - lr: 0.0010
# Epoch 125/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4423 - mean_io_u: 0.4865 - accuracy: 0.8123 - val_loss: 0.4482 - val_mean_io_u: 0.3777 - val_accuracy: 0.8219 - lr: 0.0010
# Epoch 126/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4567 - mean_io_u: 0.4715 - accuracy: 0.8029 - val_loss: 0.4667 - val_mean_io_u: 0.3782 - val_accuracy: 0.8183 - lr: 0.0010
# Epoch 127/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4608 - mean_io_u: 0.4743 - accuracy: 0.8107 - val_loss: 0.4927 - val_mean_io_u: 0.3764 - val_accuracy: 0.8079 - lr: 0.0010
# Epoch 128/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4431 - mean_io_u: 0.4673 - accuracy: 0.8153 - val_loss: 0.4748 - val_mean_io_u: 0.3751 - val_accuracy: 0.8200 - lr: 0.0010
# Epoch 129/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4336 - mean_io_u: 0.4346 - accuracy: 0.8132 - val_loss: 0.4629 - val_mean_io_u: 0.3751 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 130/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4364 - mean_io_u: 0.4443 - accuracy: 0.8121 - val_loss: 0.4606 - val_mean_io_u: 0.3760 - val_accuracy: 0.8199 - lr: 0.0010
# Epoch 131/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4293 - mean_io_u: 0.4788 - accuracy: 0.8192 - val_loss: 0.4508 - val_mean_io_u: 0.3801 - val_accuracy: 0.8187 - lr: 0.0010
# Epoch 132/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4257 - mean_io_u: 0.5092 - accuracy: 0.8200 - val_loss: 0.4355 - val_mean_io_u: 0.3783 - val_accuracy: 0.8231 - lr: 0.0010
# Epoch 133/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4337 - mean_io_u: 0.5037 - accuracy: 0.8112 - val_loss: 0.4392 - val_mean_io_u: 0.3779 - val_accuracy: 0.8225 - lr: 0.0010
# Epoch 134/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4257 - mean_io_u: 0.4975 - accuracy: 0.8142 - val_loss: 0.4553 - val_mean_io_u: 0.3782 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 135/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4136 - mean_io_u: 0.4986 - accuracy: 0.8240 - val_loss: 0.4612 - val_mean_io_u: 0.3811 - val_accuracy: 0.8158 - lr: 0.0010
# Epoch 136/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4400 - mean_io_u: 0.5122 - accuracy: 0.8108 - val_loss: 0.4428 - val_mean_io_u: 0.3805 - val_accuracy: 0.8232 - lr: 0.0010
# Epoch 137/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4104 - mean_io_u: 0.5064 - accuracy: 0.8178 - val_loss: 0.4265 - val_mean_io_u: 0.3820 - val_accuracy: 0.8269 - lr: 0.0010
# Epoch 138/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4042 - mean_io_u: 0.5077 - accuracy: 0.8219 - val_loss: 0.4310 - val_mean_io_u: 0.3864 - val_accuracy: 0.8268 - lr: 0.0010
# Epoch 139/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4035 - mean_io_u: 0.5173 - accuracy: 0.8226 - val_loss: 0.4430 - val_mean_io_u: 0.3851 - val_accuracy: 0.8243 - lr: 0.0010
# Epoch 140/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3989 - mean_io_u: 0.5138 - accuracy: 0.8264 - val_loss: 0.4342 - val_mean_io_u: 0.3811 - val_accuracy: 0.8268 - lr: 0.0010
# Epoch 141/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4056 - mean_io_u: 0.5031 - accuracy: 0.8214 - val_loss: 0.4248 - val_mean_io_u: 0.3822 - val_accuracy: 0.8277 - lr: 0.0010
# Epoch 142/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4049 - mean_io_u: 0.5075 - accuracy: 0.8186 - val_loss: 0.4220 - val_mean_io_u: 0.3890 - val_accuracy: 0.8265 - lr: 0.0010
# Epoch 143/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4081 - mean_io_u: 0.5357 - accuracy: 0.8206 - val_loss: 0.4219 - val_mean_io_u: 0.3866 - val_accuracy: 0.8279 - lr: 0.0010
# Epoch 144/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.4154 - mean_io_u: 0.5294 - accuracy: 0.8188 - val_loss: 0.4270 - val_mean_io_u: 0.3805 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 145/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3986 - mean_io_u: 0.5036 - accuracy: 0.8211 - val_loss: 0.4303 - val_mean_io_u: 0.3848 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 146/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3840 - mean_io_u: 0.5162 - accuracy: 0.8300 - val_loss: 0.4230 - val_mean_io_u: 0.3969 - val_accuracy: 0.8280 - lr: 0.0010
# Epoch 147/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3859 - mean_io_u: 0.5480 - accuracy: 0.8265 - val_loss: 0.4100 - val_mean_io_u: 0.3896 - val_accuracy: 0.8312 - lr: 0.0010
# Epoch 148/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3786 - mean_io_u: 0.5398 - accuracy: 0.8309 - val_loss: 0.4083 - val_mean_io_u: 0.3809 - val_accuracy: 0.8328 - lr: 0.0010
# Epoch 149/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3925 - mean_io_u: 0.5002 - accuracy: 0.8243 - val_loss: 0.4252 - val_mean_io_u: 0.3817 - val_accuracy: 0.8282 - lr: 0.0010
# Epoch 150/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3763 - mean_io_u: 0.5159 - accuracy: 0.8316 - val_loss: 0.4300 - val_mean_io_u: 0.3838 - val_accuracy: 0.8265 - lr: 0.0010
# Epoch 151/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3780 - mean_io_u: 0.5282 - accuracy: 0.8344 - val_loss: 0.4095 - val_mean_io_u: 0.3843 - val_accuracy: 0.8335 - lr: 0.0010
# Epoch 152/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3941 - mean_io_u: 0.5338 - accuracy: 0.8212 - val_loss: 0.4066 - val_mean_io_u: 0.3843 - val_accuracy: 0.8350 - lr: 0.0010
# Epoch 153/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3637 - mean_io_u: 0.5298 - accuracy: 0.8365 - val_loss: 0.4173 - val_mean_io_u: 0.4110 - val_accuracy: 0.8324 - lr: 0.0010
# Epoch 154/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3830 - mean_io_u: 0.5527 - accuracy: 0.8279 - val_loss: 0.4247 - val_mean_io_u: 0.4224 - val_accuracy: 0.8284 - lr: 0.0010
# Epoch 155/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3913 - mean_io_u: 0.5674 - accuracy: 0.8223 - val_loss: 0.4070 - val_mean_io_u: 0.3949 - val_accuracy: 0.8358 - lr: 0.0010
# Epoch 156/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3780 - mean_io_u: 0.5378 - accuracy: 0.8305 - val_loss: 0.3975 - val_mean_io_u: 0.3891 - val_accuracy: 0.8366 - lr: 0.0010
# Epoch 157/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3891 - mean_io_u: 0.5277 - accuracy: 0.8209 - val_loss: 0.4036 - val_mean_io_u: 0.3987 - val_accuracy: 0.8350 - lr: 0.0010
# Epoch 158/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3579 - mean_io_u: 0.5444 - accuracy: 0.8353 - val_loss: 0.4145 - val_mean_io_u: 0.4161 - val_accuracy: 0.8311 - lr: 0.0010
# Epoch 159/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3669 - mean_io_u: 0.5678 - accuracy: 0.8316 - val_loss: 0.4058 - val_mean_io_u: 0.4037 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 160/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3685 - mean_io_u: 0.5503 - accuracy: 0.8312 - val_loss: 0.4029 - val_mean_io_u: 0.4005 - val_accuracy: 0.8380 - lr: 0.0010
# Epoch 161/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3948 - mean_io_u: 0.5456 - accuracy: 0.8187 - val_loss: 0.4024 - val_mean_io_u: 0.4068 - val_accuracy: 0.8384 - lr: 0.0010
# Epoch 162/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3832 - mean_io_u: 0.5517 - accuracy: 0.8220 - val_loss: 0.4048 - val_mean_io_u: 0.4195 - val_accuracy: 0.8377 - lr: 0.0010
# Epoch 163/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3534 - mean_io_u: 0.5678 - accuracy: 0.8366 - val_loss: 0.3952 - val_mean_io_u: 0.4265 - val_accuracy: 0.8376 - lr: 0.0010
# Epoch 164/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3591 - mean_io_u: 0.5768 - accuracy: 0.8343 - val_loss: 0.3819 - val_mean_io_u: 0.4074 - val_accuracy: 0.8390 - lr: 0.0010
# Epoch 165/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3600 - mean_io_u: 0.5489 - accuracy: 0.8319 - val_loss: 0.3830 - val_mean_io_u: 0.4029 - val_accuracy: 0.8394 - lr: 0.0010
# Epoch 166/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3757 - mean_io_u: 0.5342 - accuracy: 0.8322 - val_loss: 0.3915 - val_mean_io_u: 0.4074 - val_accuracy: 0.8389 - lr: 0.0010
# Epoch 167/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3478 - mean_io_u: 0.5535 - accuracy: 0.8374 - val_loss: 0.4006 - val_mean_io_u: 0.4087 - val_accuracy: 0.8381 - lr: 0.0010
# Epoch 168/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3647 - mean_io_u: 0.5574 - accuracy: 0.8340 - val_loss: 0.3936 - val_mean_io_u: 0.3977 - val_accuracy: 0.8416 - lr: 0.0010
# Epoch 169/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3735 - mean_io_u: 0.5476 - accuracy: 0.8265 - val_loss: 0.3920 - val_mean_io_u: 0.3994 - val_accuracy: 0.8421 - lr: 0.0010
# Epoch 170/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3828 - mean_io_u: 0.5457 - accuracy: 0.8267 - val_loss: 0.3980 - val_mean_io_u: 0.4169 - val_accuracy: 0.8421 - lr: 0.0010
# Epoch 171/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3609 - mean_io_u: 0.5701 - accuracy: 0.8325 - val_loss: 0.3913 - val_mean_io_u: 0.4198 - val_accuracy: 0.8425 - lr: 0.0010
# Epoch 172/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3598 - mean_io_u: 0.5655 - accuracy: 0.8292 - val_loss: 0.3833 - val_mean_io_u: 0.4152 - val_accuracy: 0.8421 - lr: 0.0010
# Epoch 173/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3511 - mean_io_u: 0.5572 - accuracy: 0.8354 - val_loss: 0.3784 - val_mean_io_u: 0.4270 - val_accuracy: 0.8427 - lr: 0.0010
# Epoch 174/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3622 - mean_io_u: 0.5621 - accuracy: 0.8308 - val_loss: 0.3788 - val_mean_io_u: 0.4436 - val_accuracy: 0.8441 - lr: 0.0010
# Epoch 175/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3536 - mean_io_u: 0.5779 - accuracy: 0.8339 - val_loss: 0.3833 - val_mean_io_u: 0.4269 - val_accuracy: 0.8456 - lr: 0.0010
# Epoch 176/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3557 - mean_io_u: 0.5629 - accuracy: 0.8295 - val_loss: 0.3881 - val_mean_io_u: 0.4248 - val_accuracy: 0.8464 - lr: 0.0010
# Epoch 177/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3528 - mean_io_u: 0.5578 - accuracy: 0.8351 - val_loss: 0.3803 - val_mean_io_u: 0.4479 - val_accuracy: 0.8462 - lr: 0.0010
# Epoch 178/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3448 - mean_io_u: 0.5757 - accuracy: 0.8374 - val_loss: 0.3794 - val_mean_io_u: 0.4749 - val_accuracy: 0.8467 - lr: 0.0010
# Epoch 179/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3836 - mean_io_u: 0.5814 - accuracy: 0.8222 - val_loss: 0.3952 - val_mean_io_u: 0.4595 - val_accuracy: 0.8476 - lr: 0.0010
# Epoch 180/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3502 - mean_io_u: 0.5818 - accuracy: 0.8321 - val_loss: 0.3957 - val_mean_io_u: 0.4504 - val_accuracy: 0.8480 - lr: 0.0010
# Epoch 181/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3443 - mean_io_u: 0.5778 - accuracy: 0.8357 - val_loss: 0.3793 - val_mean_io_u: 0.4634 - val_accuracy: 0.8477 - lr: 0.0010
# Epoch 182/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3318 - mean_io_u: 0.5816 - accuracy: 0.8416 - val_loss: 0.3697 - val_mean_io_u: 0.5031 - val_accuracy: 0.8471 - lr: 0.0010
# Epoch 183/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3533 - mean_io_u: 0.6005 - accuracy: 0.8343 - val_loss: 0.3795 - val_mean_io_u: 0.4718 - val_accuracy: 0.8476 - lr: 0.0010
# Epoch 184/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3454 - mean_io_u: 0.5916 - accuracy: 0.8355 - val_loss: 0.3964 - val_mean_io_u: 0.4243 - val_accuracy: 0.8485 - lr: 0.0010
# Epoch 185/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3545 - mean_io_u: 0.5614 - accuracy: 0.8317 - val_loss: 0.4020 - val_mean_io_u: 0.4185 - val_accuracy: 0.8482 - lr: 0.0010
# Epoch 186/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3550 - mean_io_u: 0.5608 - accuracy: 0.8321 - val_loss: 0.3856 - val_mean_io_u: 0.4340 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 187/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3673 - mean_io_u: 0.5700 - accuracy: 0.8289 - val_loss: 0.3694 - val_mean_io_u: 0.4739 - val_accuracy: 0.8489 - lr: 0.0010
# Epoch 188/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3623 - mean_io_u: 0.5853 - accuracy: 0.8300 - val_loss: 0.3625 - val_mean_io_u: 0.4942 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 189/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3367 - mean_io_u: 0.6004 - accuracy: 0.8370 - val_loss: 0.3658 - val_mean_io_u: 0.4992 - val_accuracy: 0.8513 - lr: 0.0010
# Epoch 190/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3329 - mean_io_u: 0.5968 - accuracy: 0.8423 - val_loss: 0.3715 - val_mean_io_u: 0.4956 - val_accuracy: 0.8525 - lr: 0.0010
# Epoch 191/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3245 - mean_io_u: 0.5976 - accuracy: 0.8433 - val_loss: 0.3733 - val_mean_io_u: 0.4813 - val_accuracy: 0.8526 - lr: 0.0010
# Epoch 192/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3440 - mean_io_u: 0.5888 - accuracy: 0.8373 - val_loss: 0.3682 - val_mean_io_u: 0.4626 - val_accuracy: 0.8536 - lr: 0.0010
# Epoch 193/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3274 - mean_io_u: 0.5861 - accuracy: 0.8410 - val_loss: 0.3667 - val_mean_io_u: 0.4635 - val_accuracy: 0.8582 - lr: 0.0010
# Epoch 194/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3362 - mean_io_u: 0.5873 - accuracy: 0.8422 - val_loss: 0.3705 - val_mean_io_u: 0.4573 - val_accuracy: 0.8589 - lr: 0.0010
# Epoch 195/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3434 - mean_io_u: 0.5840 - accuracy: 0.8352 - val_loss: 0.3797 - val_mean_io_u: 0.4554 - val_accuracy: 0.8589 - lr: 0.0010
# Epoch 196/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3174 - mean_io_u: 0.5868 - accuracy: 0.8487 - val_loss: 0.3778 - val_mean_io_u: 0.4772 - val_accuracy: 0.8572 - lr: 0.0010
# Epoch 197/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3196 - mean_io_u: 0.5921 - accuracy: 0.8458 - val_loss: 0.3588 - val_mean_io_u: 0.5069 - val_accuracy: 0.8553 - lr: 0.0010
# Epoch 198/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3616 - mean_io_u: 0.6020 - accuracy: 0.8247 - val_loss: 0.3638 - val_mean_io_u: 0.5046 - val_accuracy: 0.8566 - lr: 0.0010
# Epoch 199/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3283 - mean_io_u: 0.5994 - accuracy: 0.8418 - val_loss: 0.3719 - val_mean_io_u: 0.5088 - val_accuracy: 0.8582 - lr: 0.0010
# Epoch 200/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3501 - mean_io_u: 0.6019 - accuracy: 0.8332 - val_loss: 0.3647 - val_mean_io_u: 0.4874 - val_accuracy: 0.8586 - lr: 0.0010
# Epoch 201/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3355 - mean_io_u: 0.6014 - accuracy: 0.8364 - val_loss: 0.3678 - val_mean_io_u: 0.4626 - val_accuracy: 0.8597 - lr: 0.0010
# Epoch 202/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3218 - mean_io_u: 0.5958 - accuracy: 0.8437 - val_loss: 0.3767 - val_mean_io_u: 0.4511 - val_accuracy: 0.8609 - lr: 0.0010
# Epoch 203/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3348 - mean_io_u: 0.5849 - accuracy: 0.8369 - val_loss: 0.3787 - val_mean_io_u: 0.4508 - val_accuracy: 0.8613 - lr: 0.0010
# Epoch 204/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3497 - mean_io_u: 0.5795 - accuracy: 0.8372 - val_loss: 0.3624 - val_mean_io_u: 0.4582 - val_accuracy: 0.8619 - lr: 0.0010
# Epoch 205/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3500 - mean_io_u: 0.5853 - accuracy: 0.8293 - val_loss: 0.3589 - val_mean_io_u: 0.4725 - val_accuracy: 0.8611 - lr: 0.0010
# Epoch 206/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3260 - mean_io_u: 0.5954 - accuracy: 0.8429 - val_loss: 0.3607 - val_mean_io_u: 0.4953 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 207/260
# 1/1 [==============================] - 2s 2s/step - loss: 0.3260 - mean_io_u: 0.6078 - accuracy: 0.8418 - val_loss: 0.3612 - val_mean_io_u: 0.4999 - val_accuracy: 0.8605 - lr: 0.0010

# %%
model_para=model_history.history
path=r'trained_models\UNet\model_history\\'

# %%
filename="u_net_64_Adam_5.pkl"
file_path=path+filename
import pickle

# define dictionary

# create a binary pickle file 
f = open("u_net_64_Adam_5.pkl","wb")

# write the python object (dict) to pickle file
pickle.dump(model_para,f)
# close file
f.close()

# %%
segementation_model.evaluate(validation_dataset)
# Out:
# 13/13 [==============================] - 5s 292ms/step - loss: 0.3647 - mean_io_u: 0.5083 - accuracy: 0.8527
# [0.36466559767723083, 0.5083286762237549, 0.8527065515518188]

# %%
segementation_model.evaluate(test_dataset)
# Out:
# 6/6 [==============================] - 7s 971ms/step - loss: 0.3657 - mean_io_u: 0.4944 - accuracy: 0.8537
# [0.36572179198265076, 0.4944290518760681, 0.8537335991859436]

# %%
model_save_path=r'trained_models\UNet\\'

# %%
model_name=r'u_net.h5'
model_path=model_save_path+model_name
segementation_model.save(model_path,overwrite=False)

# %%
saved_model_path=r'/content/drive/MyDrive/ML-LaDECO/LaDECO/trained_models/UNet/u_net_64_Adam_5_best_agu.h5'

# %%
u_net=tf.keras.models.load_model(saved_model_path)

# %%
input_image=tf.expand_dims(image,axis=0)
testdata=next(iter(test_dataset))
predict=u_net.predict_on_batch(testdata[0])
predict.shape
# Out:
# (64, 256, 256, 4)

# %%
input_image=tf.expand_dims(image,axis=0)
testdata=next(iter(test_dataset))
predict=segementation_model.predict_on_batch(testdata[0])
predict.shape
# Out:
# (64, 256, 256, 4)

# %%
i=35
predicted=predict[i,:,:,:]
image=testdata[0][i]
predicted_anno=testdata[1][i]
anno=np.zeros((256,256))
for i in range(4):
  temp=predicted_anno[:,:,i].numpy()
  anno[temp==1]+=i

predicted[predicted>0.5]=1
predicted[predicted<0.5]=0
predicted=np.squeeze(predicted)
pre_anno=np.zeros((256,256))
for i in range(4):
  temp=predicted[:,:,i]
  pre_anno[temp==1]+=i

# %%
import seaborn as sns
from matplotlib.patches import Patch

fig = plt.figure(figsize=(20, 8))
fig.add_subplot(1, 3, 1)
# showing image
plt.imshow(np.squeeze(image),cmap='RdYlBu_r')
plt.axis('off')
plt.title("Thermogram")

fig.add_subplot(1, 3, 2)
cmap = sns.mpl_palette("Set2", 4)
c=sns.heatmap(data=anno, cmap=cmap, cbar=False)
plt.axis('off')
legend_handles = [Patch(color=cmap[0], label='Coating'),  # red
                  Patch(color=cmap[1], label='Substrate'),
                  Patch(color=cmap[2], label='Damaged Substrate'),
                  Patch(color=cmap[3], label='Thermal band')]  # green
plt.legend(handles=legend_handles, ncol=2, bbox_to_anchor=[0.5, 1.02], loc='upper center', fontsize=12, handlelength=.8)
fig = c.get_figure()
plt.imshow(anno1,cmap='RdYlBu_r')
plt.axis('off')
plt.title("Expected Mask")
  
# Adds a subplot at the 3rd position
fig.add_subplot(1, 3, 3)
cmap = sns.mpl_palette("Set2", 4)
c=sns.heatmap(data=pre_anno, cmap=cmap, cbar=False)
plt.axis('off')
legend_handles = [Patch(color=cmap[0], label='Coating'),  # red
                  Patch(color=cmap[1], label='Substrate'),
                  Patch(color=cmap[2], label='Damaged Substrate'),
                  Patch(color=cmap[3], label='Thermal band')]  # green
plt.legend(handles=legend_handles, ncol=2, bbox_to_anchor=[0.5, 1.02], loc='upper center', fontsize=12, handlelength=.8)
fig = c.get_figure()

plt.imshow(pre_anno,cmap='RdYlBu_r')
plt.title("Predicted Mask")
#plt.savefig("Documents/U_net_train_prediction.png",dpi=100,bbox_inches='tight',transparent=True)
# Out:
# Text(0.5, 1.0, 'Predicted Mask')
